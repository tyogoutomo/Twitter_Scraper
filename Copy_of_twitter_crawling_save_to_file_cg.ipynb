# %% [markdown]
# <a href="https://colab.research.google.com/github/tyogoutomo/Twitter_Scraper/blob/main/Copy_of_twitter_crawling_save_to_file_cg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install the prerequisite requirements

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
from google.colab import drive  # to mount Google Drive to Colab notebook
from google.colab import files  # for accessing files on gdrive
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import datetime
import json, time, sys
import csv

# %% [markdown]
# from tweepy.streaming import StreamListener
# from tweepy import OAuthHandler
# from tweepy import Stream
# import datetime
# import json, time, sys
# import csv

# %%
# Mounting Google Drive

drive.mount('/content/gdrive')
path = './gdrive/My Drive/'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Crawl data from Twitter using Tweepy

# %%
hashtag = '#omicron'

# %%
## Crawl from all region

import tweepy

#consumer_key = '9LFWnBxwdvt7TwdJV34yg3kYy'
#consumer_secret = 'yrIGfET1B66ZOcWDd14gY2cbYTE2k2fdYMdlq9OXzcJzz4oKPk'
#access_token = '48964820-M2l6aZnZRw1DWgO9KpNPyYNmHkXI6sEC8vERbhy3g'
#access_secret = 'QrgDm2e15m0NqyymkVwAYoGCbcj9Mjk3hOKGse4RECqv6'

consumer_key = 'iMSMkTS14XLWOxVOl7fk1gu7z'
consumer_secret = '5szpLeV5j4PMSgbfSRN836GOe3mI1i8R3ybIemfTiihPpfhxir'
access_token = '48964820-XvfxsRbwKewFWMZqu4aIGbdrIk6TZnFmQ3CXhLKmf'
access_secret = 'zpW8VIJnwrJX5h2PJgResyBCfJCXDdODjV1hayw2epIqB'

tweetsPerQry = 1000
maxTweets = 1000
# hashtag = "#omicron"

#with open('./gdrive/My Drive/datatweet.txt', 'w') as f:
#	f.write('today''s data')


authentication = tweepy.OAuthHandler(consumer_key, consumer_secret)
authentication.set_access_token(access_token, access_secret)
api = tweepy.API(authentication, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
maxId = -1
tweetCount = 0
while tweetCount < maxTweets:
	if(maxId <= 0):
		newTweets = api.search(q=hashtag, count=tweetsPerQry, result_type="recent", tweet_mode="extended", display_text_range = 100000000)
	else:
		newTweets = api.search(q=hashtag, count=tweetsPerQry, max_id=str(maxId - 1), result_type="recent", tweet_mode="extended", display_text_range = 100000000)

	print(newTweets)
	
	if not newTweets:
		print("Tweet Habis")
		f.write("Tweet Habis")
		break
	
	for tweet in newTweets:
#		print(tweet.full_text.encode('utf-8'))
		print(tweet.full_text)
		with open('/content/gdrive/MyDrive/Google Collabs/datatweet.txt', 'a+', newline='') as f:
			f.write(tweet.full_text + ' ')

	
		
	tweetCount += len(newTweets)	
	maxId = newTweets[-1].id

# %%
## Crawl from Indonesia only

import tweepy

consumer_key = '9LFWnBxwdvt7TwdJV34yg3kYy'
consumer_secret = 'yrIGfET1B66ZOcWDd14gY2cbYTE2k2fdYMdlq9OXzcJzz4oKPk'
access_token = '48964820-M2l6aZnZRw1DWgO9KpNPyYNmHkXI6sEC8vERbhy3g'
access_secret = 'QrgDm2e15m0NqyymkVwAYoGCbcj9Mjk3hOKGse4RECqv6'
tweetsPerQry = 1000
maxTweets = 1000
# hashtag = "#omicron"

authentication = tweepy.OAuthHandler(consumer_key, consumer_secret)
authentication.set_access_token(access_token, access_secret)
api = tweepy.API(authentication, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
#api = tweepy.API(auth)
# places = api.geo_search(query="Indonesia", granularity="country")
places = api.geo_search(query="United States", granularity="country")
place_id = places[0].id

tweets = api.search(q="place:%s" % place_id)
#tweets = api.search(q=hashtag, count=tweetsPerQry, max_id=str(maxId - 1), result_type="recent", tweet_mode="extended", display_text_range = 100000000)
#tweets = api.search(q="place:%s" % place_id, tweet_mode="extended", display_text_range = 100000000)
for tweet in tweets:
    print(tweet.text + " | " + tweet.place.name if tweet.place else "Undefined place")
    with open('/content/gdrive/MyDrive/Google Collabs/datatweet.txt', 'a+', newline='') as f:
			  f.write(tweet.text + " | " + tweet.place.name + "\n" if tweet.place else "Undefined place")
# Out:
# Dunia mai 2 chezien aise hai jo kese ki samaj mai nahi aty;
# 1: Shiekh Rashid shaadi ku nahi karta. 2: Ye Barish aur… https://t.co/PLkw33PVRL | North-west Frontier
# Salute your courage https://t.co/Riu19KBvXA | Sindh
# https://t.co/xu5d34MyPF | Punjab
# @SidShivamHero @SidJaanman @sidharth_shukla ❤✨❤✨❤ | Peshawar
# Sometimes, when you try to go closer to Allah, you lose some people. That's fine. People who loves Allah won't go f… https://t.co/g5YIsAtVta | Karachi
# @Amaliainc Wah wah wah wah wah | Karachi
# Reality Best lines
# #Parizaad https://t.co/w5GBWaC71H | Lahore
# @TehsinAbidi Thankyou so much ADI ALLAH stay Blessed | Sindh
# @Momalisaa_ Ameen❤ | Lahore
# active shooter at bundu khan 5 jan | Bundu khan
# #Aflex Billgates motivate words https://t.co/WojNUfNvep | Loralai
# In the Snow World
# #MalamJabba
# #KPK
# #LandOfHospitality https://t.co/E0t3papmna | North-west Frontier
# @ARYSabirShakir @arsched Zaati mafad bhi koi cheez hoti hy... | Punjab
# The weather. Love it. @ Islamabad, Pakistan https://t.co/QL7uuEGqEC | Islamabad
# @mayaali07 Queen of hearts❣ | Karachi

# %% [markdown]
# start processing data

# %%
import re
import string
import operator
from collections import Counter

c = Counter()
# sorted_x_split_list = ['']
frequency = {}

stop_words = ['is', 'that', 'and', 'this', 'or', 'these', 'those', 'https', 'graphql', 'hashtag', 'instagram', 'fna',
             'fbcdn', 'net', 'jpg', 'src', 'the', 'not', 'from', 'than', 'for', 'ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than'
              'dan', 'dari', 'untuk', 'yang', 'dengan', 'level', 'ini', 'itu', 'dalam', 'nya', 'kan', 'bintaro', 'mfanolyte', 'jln', 'atk']

#if reading from file
#document_text = open("data-crawling.txt", "r") #the input text
document_text = open("/content/gdrive/MyDrive/Google Collabs/datatweet.txt", "r")

text_string = document_text.read().lower() #convert input text to lower case
match_pattern = re.findall(r'\b[a-z]{3,15}\b', text_string) #regex for removing symbols

for word in match_pattern:
    if word not in stop_words:
        count = frequency.get(word, 0)
        frequency[word] = count + 1
        
#for k, v in frequency.items():        
#    print(k, v)
    
#frequency_list = frequency.keys()
#frequency_values = frequency.values()
#frequency_items = frequency.items()
        
sorted_x = sorted(frequency.items(), key=operator.itemgetter(1), reverse = True)

#s = sorted(frequency_list())
#s = sorted(frequency.items(), key=lambda value: value[1])

#for words in frequency_list:
#for words in sorted_x:
#    print( words, frequency[words])

sorted_x

  # sorted_x_split_list = sorted_x_split_list.append(sorted_x_split)
# print(sorted_x_split_0)
# with open('/content/gdrive/MyDrive/Google Collabs/datatweet.txt', 'w', newline='') as txtwrite:
#   data = txtwrite.write(sorted_x[0])

#document_text.close()

################################################################################

new_data = ''

for word in match_pattern:
    if word not in stop_words:
        count = frequency.get(word, 0)
        frequency[word] = count + 1
        new_data = new_data + ' ' + word
  
print(new_data)
# Out:
#  harryspoelstra belgium update cases icu ventilator deaths coderedearth noahtzedek right noah try update stat running using study ericdjuly almost omicron cases germany vaccinated individuals notice seeing far fewer vaxxed unvaxxed isglobalorg una pandemia global una respuesta local sirve mucho frente frente nuevas variantes que puedan dan murphy deliver omicron brisbane quarantine les enfants pour covid atteignent des records semaine enfants ont admis spkalantri must ask molnupiravir hands raw deal children couple trying conceive amp women already pre positive omicron view upsurge omicron cases district ramban administration ordered passengers amp tourists travelling bus cabs taxis tempo travellers personal vehicles shall undergo rapid antigen test covid compulsorily patnitop onlineegitim drfahrettinkoca aofanadolum omicron stiyoruz beaucoup commencent poser des questions trop omicron dose des cas thrombose positive omicron positive omicron positive omicron edwyplenel question serait plus vaudrait pas mieux laisser omicron circuler pour avoir une collecti pendant que emmanuelmacron veut emmerder les les danois effectuent des recherches tablent sur imm spokesperson taliban cries says thank modiji sending vaccines one macron constatant que vaccination marche pas son sur les vegtdoor studie vergelijking verschil risico tussen omicron delta variant uitkomst zeer geruststellend voor alle leeftijds much appreciated move incindia incuttarpradesh omicron omicron disrupts systems qauqonpili place get key global india amp state resources rel positive omicron medicalfollower veran omicron les vaccins propagation virus vos poumons vos poumons remplir todo muy mild pero los hospitales llenitos primaria petada dedicada exclusiv positive omicron positive omicron korona koronafi koronapassi rokotepassi omicronvariant omicron omikron antigeenitesti pikatesti nhsamwnwnp official hongkong ban restaurant dining totally nonsensical policy arbitrary cuto latest data south africa reflecting rise deaths still nationally link cases acute outc pokrath update omicron stephenhdg ducatikiwi pile body bags streets piling pandemic pandemic know omicron heavy cold vijaythehindu full lockdown sunday tamilnadu omicron drscotthadland cold isn serious kids pediatrician amp dad promise want child vegtdoor studie vergelijking verschil risico tussen omicron delta variant uitkomst zeer geruststellend voor alle leeftijds cela sont que les parle pas reste des centaines milliers effets secondaires beaucoup commencent poser des questions trop omicron dose des cas thrombose chennaitimestoi television presenter commentator suhailchandhok acted ajith starrer veeram tested positive airnewshindi httweets scientists france identified new mutated strain omicron researchers say contains mutatio vijaythehindu full lockdown sunday tamilnadu omicron oscargenomics que omicron era menos preocupante nunca fue buen mensaje pacientes uci por habitantes itsjskillz omicron china xian lockdown ambulances amass neighborhood later taken away talk coming people positive omicron sad news awaited movie poojahegde prabhas radheshyam postponed due omicron issue hegdepooja radheshyam coronavirus omicron ihuvariant florana tnlockdown lockdown tamilnadu beaucoup commencent poser des questions trop omicron dose des cas thrombose aravindhanips public chengalpattu district requested mask vaccinate drink kabasura kudineer maintain social distanc modi traitor hushed ivermectin brought covid shutdown india harmles irupnd spike omicron cases india specially bengal happened due celebrations media written andrebercoff omicron macron question avec les pari est qui emmerde mieux estratti dell intervista virologo geert vanden bossche vaccinazione massa genera varianti dominanti non positive omicron official hongkong ban restaurant dining totally nonsensical policy arbitrary cuto motorwars omicron hongkong vietato voli provenienti otto paesi causa della diffusione della variante omicron del coronavirus balik a ...

# %%
keyword = sorted_x[0]
print(keyword)
# Out:
# ('jakarta', 767)

# %% [markdown]
# export data to csv for visualization

# %%
import csv

with open('/content/gdrive/MyDrive/Google Collabs/datatweet_parsed.csv', 'w', newline='') as csvfile:
      wr = csv.writer(csvfile)
      wr.writerow(sorted_x)

# %% [markdown]
# bikin wordcloud

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.19.5)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
# data = open('/content/gdrive/MyDrive/datatweet.txt', 'r')
# print (data)

# data = match_pattern

with open('/content/gdrive/MyDrive/Google Collabs/datatweet_parsed.txt', 'r', newline='') as txtread:
  data = txtread.read()
  print(data)

# %%
# wc = WordCloud().generate(data)
wc = WordCloud().generate(new_data)

# %%
plt.imshow(wc)

# %%
wc = WordCloud(width=1000, height=1000, background_color="white", stopwords=STOPWORDS).generate(new_data)

plt.figure(figsize=(15, 15))
plt.axis("off")
plt.imshow(wc)

# %%
import seaborn as sns
sns.set()

planets = sns.load_dataset('planets')
planets.head()
print(planets)
print('----------')
print(type(planets))

# planets = new_data

with sns.axes_style('white'):
    g = sns.factorplot("year", data=planets, aspect=4.0, kind='count',
                       hue='method', order=range(2001, 2015))
    g.set_ylabels('Number of Planets Discovered')
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]
# ----------
# <class 'pandas.core.frame.DataFrame'>
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Write crawled data + its freq to csv file (for seaborn plot)

# %%
sorted_x_len = len(sorted_x)
print(sorted_x_len)
pattern = "\W" #"\b^(),' \b"
sorted_x_list = []
tyo = {}
keyword = "ppkm"

with open('/content/gdrive/MyDrive/Google Collabs/datatweet_parsed.csv', 'a+', newline='') as csvfile:
  wr = csv.writer(csvfile)
  wr.writerow(['keyword,value'])

# for i in range (0,sorted_x_len):
for i in range (0,5):
  sorted_x_split = str(sorted_x[i])
  
  print(sorted_x_split)
  # sorted_x_split = str(sorted_x_split.split(', '))
  eliminate_symbol = re.split(pattern, sorted_x_split) #regex for removing symbols
  sorted_x_split_word = eliminate_symbol[2]
  sorted_x_split_freq = eliminate_symbol[5]
  print(sorted_x_split_word)
  print(sorted_x_split_freq)

  tyo.update([(sorted_x_split_word, int(sorted_x_split_freq))])

  # apa ini pusing??
  eliminate_string = eliminate_symbol[2]
  if eliminate_string == keyword:
    eliminate_string_ammount = eliminate_symbol[5]
    print(eliminate_string_ammount)
  else:
    pass

  # sorted_x_list.append(eliminate_symbol[2])
  # print(sorted_x_split[0])	
  '''with open('/content/gdrive/MyDrive/Google Collabs/datatweet_parsed.txt', 'a+', newline='') as f:
    # f.write(sorted_x_list)
    f.write(eliminate_string + "\n")'''

  with open('/content/gdrive/MyDrive/Google Collabs/datatweet_parsed.csv', 'a+', newline='') as csvfile:
      wr = csv.writer(csvfile)
      wr.writerow([sorted_x_split_word+','+sorted_x_split_freq])
# Out:
# 3549
# ('omicron', 751)
# omicron
# 751
# ('des', 129)
# des
# 129
# ('positive', 111)
# positive
# 111
# ('covid', 89)
# covid
# 89
# ('les', 82)
# les
# 82

# %% [markdown]
# Visualization using matplotlib
#
# -still cannot limit the data shown to the most 3 only

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline

# tyo = {"ppkm" : 100, "tyo" : 0, "omicron" : 200, "vaksin" : 99}
# tyo = tyo
keys = list(tyo.keys())
values = list(tyo.values())

# plt.bar(range(len(tyo)), values, tick_label=keys)
# plt.xlim(5,1)

## new code to make it more customizable ##
plt.figure(figsize=[14, 7])
col_map = plt.get_cmap('tab20')

# Creating a bar chart from the DataFrame df
pl = plt.bar(keys, values, width=0.5, color=col_map.colors, 
        edgecolor='black', linewidth=3)

for bar in pl:
    plt.annotate(bar.get_height(), 
                 xy=(bar.get_x()+0.07, bar.get_height()+10), 
                     fontsize=15)
plt.title(f'Twitter Recap for {hashtag}', fontsize=15)
plt.xlabel('Keyword', fontsize=15)
plt.ylabel('Frequency', fontsize=15)

plt.show()
